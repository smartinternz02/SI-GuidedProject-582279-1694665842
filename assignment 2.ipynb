# %%
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming you have a DataFrame called 'df' with columns 'alcohol' and 'speeding'

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data=sns.load_dataset("car_crashes")

# %%
data.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
    sns.boxplot(data["speeding"])
# Out:
# <Axes: >

# %%
#here we can see that minimum is near to 3.8
#medium is near to 4.6
#and maximum of speeding 6.4

# %%
data.describe()
# Out:
#            total   speeding    alcohol  not_distracted  no_previous  \
# count  51.000000  51.000000  51.000000       51.000000    51.000000
# mean   15.790196   4.998196   4.886784       13.573176    14.004882
# std     4.122002   2.017747   1.729133        4.508977     3.764672
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# 25%    12.750000   3.766500   3.894000       10.478000    11.348000
# 50%    15.600000   4.608000   4.554000       13.857000    13.775000
# 75%    18.500000   6.439000   5.604000       16.140000    16.755000
# max    23.900000   9.450000  10.038000       23.661000    21.280000
#
#        ins_premium  ins_losses
# count    51.000000   51.000000
# mean    886.957647  134.493137
# std     178.296285   24.835922
# min     641.960000   82.750000
# 25%     768.430000  114.645000
# 50%     858.970000  136.050000
# 75%    1007.945000  151.870000
# max    1301.520000  194.780000

# %%
sns.lineplot(data = data,x="alcohol",y="speeding")
# Out:
# <Axes: xlabel='alcohol', ylabel='speeding'>

# %%
#we see that alcohol content is increasing graduall speeding is also incresing

# %%
sns.scatterplot(data =data ,x="alcohol",y="speeding")
# Out:
# <Axes: xlabel='alcohol', ylabel='speeding'>

# %%
#alcohol and sppeding both are incresing gradually

# %%
sns.barplot(data=data,x="alcohol",y="speeding")
# Out:
# <Axes: xlabel='alcohol', ylabel='speeding'>

# %%
#above is the barplot representation of alchol with speed

# %%
data.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
data.columns
# Out:
# Index(['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous',
#        'ins_premium', 'ins_losses', 'abbrev'],
#       dtype='object')

# %%
sns.relplot(data = data ,x ="speeding" ,y="alcohol")

# %%
#inference when speeding is increasing alocohol content is also increasing gradually

# %%
sns.scatterplot( data = data , x = "alcohol" , y = "not_distracted")
# Out:
# <Axes: xlabel='alcohol', ylabel='not_distracted'>

# %%
#it is a very unique that when alcohol content increases they are not sitracted

# %%
sns.histplot(data=data,x="total",binwidth=1,kde = True)
plt.xlabel("Totall crashed")
plt.ylabel("Freq")
# Out:
# Text(0, 0.5, 'Freq')

# %%
#frequency of car crashing is like a beel shaped

# %%
# Out:
# <Axes: xlabel='speeding', ylabel='count'>

# %%
sns.violinplot(data=data , x="alcohol")
# Out:
# <Axes: xlabel='alcohol'>

# %%
sns.regplot(data = data , x="total" , y = "alcohol")
plt.xlabel("Total crashed")
plt.ylabel("alcohol consumption")
plt.title("regression")
# Out:
# Text(0.5, 1.0, 'regression')
